# %% [markdown]
# #  Downloading data for loop detection task
#
# This notebook illustrates how to download the data files from ENCODE and 4DN database.

# %%
#add configuration for the notebook to read excel files
# !pip install openpyxl

# %%
# step 1: get the downloading link
import pandas as pd
xls = pd.ExcelFile('../data/Supplementary_Table_hicfoundation.xlsx')

# Now you can list all sheets in the file
# xls.sheet_names
df = pd.read_excel('../data/Supplementary_Table_hicfoundation.xlsx', sheet_name="Sup5",header=1)
url_list = df['File Download URL']

# %%
# step 2: download the related data
import os 
def download_encode(output_dir,url):
    root_path =  os.getcwd()
    os.chdir(output_dir)
    os.system("wget %s"%url)
    os.chdir(root_path)
def download_4dn(output_dir,url,user_key):
    root_path =  os.getcwd()
    os.chdir(output_dir)
    
    os.system(f"curl -O -L --user {user_key} {url}")
    os.chdir(root_path)
def download_hic(dataset_list,output_dir,user_key):
    for dataset in dataset_list:
        url=dataset
        if "4DN" in dataset:
            download_4dn(output_dir,url,user_key=user_key)
        elif "EN" in dataset:
            download_encode(output_dir,url)
        else:
            print("Unknown dataset %s"%dataset)


#specify output direcotry
output_dir="reproducibility_data"#change it to your own directory
os.makedirs(output_dir,exist_ok=True)
#download hic data
user_key = "USER:PASSWORD"
#Please create the accession key in your profile in https://data.4dnucleome.org.
#this should be configured through https://data.4dnucleome.org/help/user-guide/downloading-files

if user_key=="USER:PASSWORD":
    print("Please configure the user key for 4DN")
    print("Detailed instruction is in https://data.4dnucleome.org/help/user-guide/downloading-files")
    print("You can add the key in your profile in https://data.4dnucleome.org.")
    exit()
download_hic(url_list,output_dir,user_key)
# Out:
#    Organism                                          Biosource  \
# 0     mouse                                                46C
# 1     mouse                                                46C
# 2     mouse                                      F123-CASTx129
# 3     mouse                                      F123-CASTx129
# 4     mouse                                            G1E-ER4
# 5     mouse                                            G1E-ER4
# 6     mouse                                     granulosa cell
# 7     mouse                                     granulosa cell
# 8     human                                              HepG2
# 9     human                                              HepG2
# 10    human                                             IMR-90
# 11    human                                             IMR-90
# 12    mouse                                          mESC line
# 13    mouse                                          mESC line
# 14    mouse                            olfactory receptor cell
# 15    mouse                            olfactory receptor cell
# 16    mouse                                           scid.adh
# 17    mouse                                           scid.adh
# 18    mouse                                       Sertoli cell
# 19    mouse                                       Sertoli cell
# 20    mouse                                             T cell
# 21    mouse                                             T cell
# 22    human  H9 with targeted integration of GFP-tagged MYL...
# 23    human  H9 with targeted integration of GFP-tagged MYL...
# 24    human                                            HeLa-S3
# 25    human                                            HeLa-S3
# 26    human                                  heart left atrium
# 27    human                                  heart left atrium
# 28    human        CyT49 differentiated to definitive endoderm
# 29    human        CyT49 differentiated to definitive endoderm
#
#    Experiment Type       #Reads  #Reads(Off-Diagonal)  Replicate Info  \
# 0     in situ Hi-C   905.076143            672.545480               2
# 1     in situ Hi-C   642.317727            516.761292               1
# 2     in situ Hi-C   558.684826            428.802909               2
# 26      4DNESJ98FIW5   4DNFI5WS8M6X
# 27      4DNESJ98FIW5   4DNFIJCEPTFH
# 28      4DNESV11RYSF   4DNFI4LG5248
# 29      4DNESV11RYSF   4DNFIKZHGYEO
#
#                                     File Download URL  split   Loop F1  \
# 0   https://data.4dnucleome.org/files-processed/4D...   test  0.694318
# 1   https://data.4dnucleome.org/files-processed/4D...   test  0.694318
# 2   https://data.4dnucleome.org/files-processed/4D...   test  0.624817
# 3   https://data.4dnucleome.org/files-processed/4D...   test  0.624817
# 4   https://data.4dnucleome.org/files-processed/4D...   test  0.671014
# 5   https://data.4dnucleome.org/files-processed/4D...   test  0.671014
# 6   https://data.4dnucleome.org/files-processed/4D...   test  0.686354
# 7   https://data.4dnucleome.org/files-processed/4D...   test  0.686354
# 8   https://data.4dnucleome.org/files-processed/4D...   test  0.728072
# 9   https://data.4dnucleome.org/files-processed/4D...   test  0.728072
# 10  https://www.encodeproject.org/files/ENCFF648KB...   test  0.644641
# 11  https://www.encodeproject.org/files/ENCFF632TG...   test  0.644641
# 12  https://data.4dnucleome.org/files-processed/4D...   test  0.689051
# 13  https://data.4dnucleome.org/files-processed/4D...   test  0.689051
# 14  https://data.4dnucleome.org/files-processed/4D...   test  0.732622
# 15  https://data.4dnucleome.org/files-processed/4D...   test  0.732622
# 16  https://data.4dnucleome.org/files-processed/4D...   test  0.638898
# 17  https://data.4dnucleome.org/files-processed/4D...   test  0.638898
# 18  https://data.4dnucleome.org/files-processed/4D...   test  0.802752
# 19  https://data.4dnucleome.org/files-processed/4D...   test  0.802752
# 20  https://data.4dnucleome.org/files-processed/4D...   test  0.642479
# 21  https://data.4dnucleome.org/files-processed/4D...   test  0.642479
# 22  https://data.4dnucleome.org/files-processed/4D...  train  0.692624
# 23  https://data.4dnucleome.org/files-processed/4D...  train  0.692624
# 24  https://data.4dnucleome.org/files-processed/4D...  train  0.773328
# 25  https://data.4dnucleome.org/files-processed/4D...  train  0.773328
# 26  https://data.4dnucleome.org/files-processed/4D...  train  0.707492
# 27  https://data.4dnucleome.org/files-processed/4D...  train  0.707492
# 28  https://data.4dnucleome.org/files-processed/4D...  train  0.665358
# 29  https://data.4dnucleome.org/files-processed/4D...  train  0.665358
#
#     Loop Count  #Consensus Loop
# 0         6071             3999
# 1         5770             3999
# 2         3106             2041
# 3         3771             2041
# 4         3207             2179
# 5         3612             2179
# 6         4451             2560
# 7         3161             2560
# 8        11770             7032
# 9         8658             7032
# 10        5688             4459
# 11        8774             4459
# 12        6840             3963
# 13        5019             3963
# 14        7145             4738
# 15        6329             4738
# 16        6175             5471
# 17       12175             5471
# 18       10006             7736
# 19       10431             7736
# 20        1545              982
# 21        1674              982
# 22        3734             2565
# 23        4966             2565
# 24       15676            11998
# 25       16330            11998
# 26        4404             2716
# 27        3504             2716
# 28        6584             4209
# 29        7175             4209
