# %% [markdown]
# #  Downloading data for reproducibility task
#
# This notebook illustrates how to download the data files from ENCODE and 4DN database.

# %%
# step 1: get the downloading link
import pandas as pd
xls = pd.ExcelFile('../data/Supplementary_Table_hicfoundation.xlsx')

# Now you can list all sheets in the file
# xls.sheet_names
df = pd.read_excel('../data/Supplementary_Table_hicfoundation.xlsx', sheet_name="Sup3",header=1)
url_list = df['File Download URL']

# %%
# step 2: download the hic data
import os 
def download_encode(output_dir,url):
    root_path =  os.getcwd()
    os.chdir(output_dir)
    os.system("wget %s"%url)
    os.chdir(root_path)
def download_4dn(output_dir,url,user_key):
    root_path =  os.getcwd()
    os.chdir(output_dir)
    
    os.system(f"curl -O -L --user {user_key} {url}")
    os.chdir(root_path)
def download_hic(dataset_list,output_dir,user_key):
    for dataset in dataset_list:
        if "4DN" in dataset:
            url = f"https://data.4dnucleome.org/files-processed/{dataset}/@@download/{dataset}.hic"
            download_4dn(output_dir,url,user_key=user_key)
        elif "ENCSR" in dataset:
            url=f"https://www.encodeproject.org/files/{dataset}/@@download/{dataset}.hic"
            download_encode(output_dir,url)
        else:
            print("Unknown dataset %s"%dataset)


#specify output direcotry
output_dir="reproducibility_data"#change it to your own directory
os.makedirs(output_dir,exist_ok=True)
#download hic data
user_key = "USER:PASSWORD"
#Please create the accession key in your profile in https://data.4dnucleome.org.
#this should be configured through https://data.4dnucleome.org/help/user-guide/downloading-files

if user_key=="USER:PASSWORD":
    print("Please configure the user key for 4DN")
    print("Detailed instruction is in https://data.4dnucleome.org/help/user-guide/downloading-files")
    print("You can add the key in your profile in https://data.4dnucleome.org.")
    exit()
download_hic(url_list,output_dir,user_key)
# Out:
#     Organism                             Biosource Experiment Type  split  \
# 0      human           astrocyte of the cerebellum   Dilution Hi-C  train
# 1      human           astrocyte of the cerebellum   Dilution Hi-C  train
# 2      human          astrocyte of the spinal cord   Dilution Hi-C  train
# 3      human          astrocyte of the spinal cord   Dilution Hi-C  train
# 4      human  brain microvascular endothelial cell   Dilution Hi-C  train
# ..       ...                                   ...             ...    ...
# 123    human                                  T47D    in situ Hi-C   test
# 124    mouse                             thymocyte    in situ Hi-C   test
# 125    mouse                             thymocyte    in situ Hi-C   test
# 126    mouse                                zygote    in situ Hi-C   test
# 127    mouse                                zygote    in situ Hi-C   test
#
#      Replicate Info  #Reads(Off-Diagonal) Dataset Accession File Accession  \
# 0                 2            125.873885      4DNESRA7OFS4   4DNFISNLJWVH
# 1                 1            130.263548      4DNESRA7OFS4   4DNFIVSPDVD2
# 2                 1             38.104088      4DNES4ABKY9M   4DNFI5463BGB
# 3                 2             42.844645      4DNES4ABKY9M   4DNFI7TR3V8M
# 4                 2             44.115165      4DNES7YXSK37   4DNFIHUXVEYU
# ..              ...                   ...               ...            ...
# 123               1             32.819918       ENCSR549MGQ    ENCFF142GAK
# 124               1             77.777866      4DNESJWSHRA5   4DNFIB54P8UN
# 125               2             12.499899      4DNESJWSHRA5   4DNFIZUA7ARB
# 126               2             24.109165      4DNES1J8MC4Q   4DNFI4T1IM11
# 127               1             30.828815      4DNES1J8MC4Q   4DNFI3JD3XNX
#
#                                      File Download URL
# 0    https://data.4dnucleome.org/files-processed/4D...
# 1    https://data.4dnucleome.org/files-processed/4D...
# 2    https://data.4dnucleome.org/files-processed/4D...
# 3    https://data.4dnucleome.org/files-processed/4D...
# 4    https://data.4dnucleome.org/files-processed/4D...
# ..                                                 ...
# 123  https://www.encodeproject.org/files/ENCFF142GA...
# 124  https://data.4dnucleome.org/files-processed/4D...
# 125  https://data.4dnucleome.org/files-processed/4D...
# 126  https://data.4dnucleome.org/files-processed/4D...
# 127  https://data.4dnucleome.org/files-processed/4D...
#
# [128 rows x 9 columns]
